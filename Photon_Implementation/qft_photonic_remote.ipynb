# %% [markdown]
# # Photonic Quantum Fourier Transform Remote Simulation

# %%
# first install perceval using ```pip install perceval-quandela```
import numpy as np
import matplotlib.pyplot as plt

import perceval as pcvl
import perceval.components as comp
from perceval import Processor, BasicState
from perceval.algorithm import Sampler
pcvl.__version__
# Out:
# '1.1.0'

# %% [markdown]
# ### Setting Remote Config Token

# %%
# set remote config token
from perceval import RemoteConfig

# put api key here
API_KEY = ""

remote_config = RemoteConfig()
remote_config.save()

# %%
def bitstring_to_fock(bitstring):
    # if the parameter is a string, make it a list of ints
    if isinstance(bitstring, str):
        bits = [int(b) for b in bitstring]
    else:
        bits = list(bitstring)

    n = len(bits)
    N = 2 ** n
    index = int("".join(str(b) for b in bits), 2)

    occ = [0] * N
    occ[index] = 1

    # basic state is fock state w/ perceval
    return BasicState(occ)

# %%
# qft matrix
def qft_matrix(num_qubits):
    N = 2 ** num_qubits
    omega = np.exp(2j * np.pi / N)
    matrix = np.array([[omega ** (k * l) for l in range(N)] for k in range (N)], dtype = complex) / np.sqrt(N)

    return pcvl.Matrix(matrix)

# %%
# unitary of the qft
def qft_unitary_component(num_qubits):
    U = qft_matrix(num_qubits)
    qft_unit = comp.Unitary(U = U)
    return qft_unit

# %%
def photonic_qft(num_qubits, bitstring, shots = 1024):
    N = 2 ** num_qubits

    qft_unitary = qft_unitary_component(num_qubits)

    processor = Processor("SLOS", qft_unitary)

    input_state = bitstring_to_fock(bitstring)
    processor.with_input(input_state)
    processor.min_detected_photons_filter(1)

    sampler = Sampler(processor)
    results = sampler.sample_count(shots)["results"]

    print("QFT unitary on", N, "modes:")
    pcvl.pdisplay(qft_unitary.U)

    return results

# %%
def normalize_counts(counts):
    total = sum(counts.values())
    return {k: v / total for k, v in counts.items()}

# %%
def plot_results(counts, title = "QFT output"):
    probabilities = normalize_counts(counts)
    states = list(probabilities.keys())
    prob_values = [float(v) for v in probabilities.values()]

    labels = [str(s) for s in states]

    plt.figure()
    plt.bar(range(len(states)), prob_values)
    plt.xticks(range(len(states)), labels, rotation = 45)
    plt.ylabel("Probability")
    plt.title(title)
    plt.ylim(0, 1.0)
    plt.tight_layout()
    plt.show()

# %%
def plot_bitstring_probabilities(counts, num_qubits, title = "QFT Output"):
    total = sum(counts.values())
    data = []

    # bs = basis state = fock state
    for bs, c in counts.items():
        occ = list(bs)
        i = occ.index(1)
        bitstr = format(i, f"0{num_qubits}b")
        prob = c / total
        data.append((i, bitstr, prob))

    data.sort(key = lambda t: t[0])

    x = [t[1] for t in data]
    y = [t[2] for t in data]

    plt.figure(figsize = (12, 5))
    plt.bar(x, y)
    plt.xticks(rotation = 60)
    plt.ylabel("Probability")
    plt.title(title)
    plt.ylim(0, 1.0)
    plt.tight_layout()

# %%
def fock_to_index(bs):
    occ = list(bs)
    return occ.index(1)

def plot_counts(counts, num_qubits, title = "Photnic QFT Result Count Distribution"):
    data = []
    for bs, c in counts.items():
        i = fock_to_index(bs)
        bitstr = format(i, f"0{num_qubits}b")
        data.append((i, bitstr, c))

    data.sort(key = lambda t: t[0])

    indices = [t[0] for t in data]
    bitlabels = [t[1] for t in data]
    counts = [t[2] for t in data]

    plt.figure(figsize = (10, 5))
    plt.bar(indices, counts)
    plt.xticks(indices, bitlabels, rotation = 60, ha = "right")
    plt.xlabel("Bitstring |x⟩")
    plt.ylabel("Counts")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Setting Up Remote Simulation

# %%
# set remote config token
from perceval import RemoteProcessor, NoiseModel
from perceval.algorithm import Sampler

# put api key here
API_KEY = ""
REMOTE_PLATFORM = "sim:belenos"

remote_config = RemoteConfig()
remote_config.set_token(API_KEY)
remote_config.save()
remote_simulator = RemoteProcessor(REMOTE_PLATFORM) 

def qft_photonic_remote(num_qubits, bitstring, shots = 1024, platform = REMOTE_PLATFORM, api_key = API_KEY, use_noise=True):
    U = qft_matrix(num_qubits)
    qft_unitary = pcvl.components.Unitary(U)

    # noise model
    noise = None
    if use_noise:
        noise = NoiseModel(transmittance = 0.1, indistinguishability = 0.95, g2 = 0.01)

    processor = RemoteProcessor(platform, api_key, noise = noise)

    try:
        processor.set_circuit(qft_unitary)
    except AttributeError:
        processor.add(0, qft_unitary)

    input_state = bitstring_to_fock(bitstring)
    processor.with_input(input_state)
    processor.min_detected_photons_filter(1)

    sampler = Sampler(processor, max_shots_per_call = shots)
    results = sampler.sample_count(shots)["results"]

    return results

# %%
# remote simulation
results_remote = qft_photonic_remote(3, "000", shots = 1024)
plot_bitstring_probabilities(results_remote, 3, "Remote Simulation of Photonic QFT with Input |000>")
plot_counts(results_remote, 3, "Counts from Remote Photonic Simulation")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[91], line 2
#       1 # remote simulation
# ----> 2 results_remote = qft_photonic_remote(3, "000", shots = 1024)
#       3 plot_bitstring_probabilities(results_remote, 3, "Remote Simulation of Photonic QFT with Input |000>")
#       4 plot_counts(results_remote, 3, "Counts from Remote Photonic Simulation")
#
# Cell In[90], line 35, in qft_photonic_remote(num_qubits, bitstring, shots, platform, api_key, use_noise)
#      32 processor.min_detected_photons_filter(1)
#      34 sampler = Sampler(processor, max_shots_per_call = shots)
# ---> 35 results = sampler.sample_count(shots)["results"]
#      37 return results
#
# File ~/QFT-Cross-Verification/perceval-env/lib/python3.12/site-packages/perceval/runtime/job.py:91, in Job.__call__(self, *args, **kwargs)
#      87 def __call__(self, *args, **kwargs) -> dict:
#      88     """
#      89     Execute the job synchronously
#      90     """
# ---> 91     return self.execute_sync(*args, **kwargs)
#
# File ~/QFT-Cross-Verification/perceval-env/lib/python3.12/site-packages/perceval/runtime/remote_job.py:253, in RemoteJob.execute_sync(self, *args, **kwargs)
#     240 def execute_sync(self, *args, **kwargs) -> dict:
#     241     """
#     242     Execute the task synchronously. This call is blocking and immediately returns a results dictionary.
#     243
#    (...)    251     :return: the results
#     252     """
# --> 253     job = self.execute_async(*args, **kwargs)
#     254     while not job.is_complete:
#     255         time.sleep(self._refresh_progress_delay)
#
# File ~/QFT-Cross-Verification/perceval-env/lib/python3.12/site-packages/perceval/runtime/remote_job.py:283, in RemoteJob.execute_async(self, *args, **kwargs)
#     281 except Exception as e:
#     282     self._job_status.stop_run(RunningStatus.ERROR, str(e))
# --> 283     raise e
#     285 return self
#
# File ~/QFT-Cross-Verification/perceval-env/lib/python3.12/site-packages/perceval/runtime/remote_job.py:277, in RemoteJob.execute_async(self, *args, **kwargs)
#     275 assert self._job_status.waiting, "job has already been executed"
#     276 try:
# --> 277     self._id = self._rpc_handler.create_job(self._create_payload_data(*args, **kwargs))
#     278     get_logger().info(f"Send payload to the Cloud (got job id: {self._id})", channel.general)
#     279     self._job_status.status = RunningStatus.WAITING
#
# File ~/QFT-Cross-Verification/perceval-env/lib/python3.12/site-packages/perceval/runtime/rpc_handler.py:148, in RPCHandler.create_job(self, payload)
#     141 """create a job
#     142
#     143 :param payload: the payload to send
#     144 :raises HTTPError: when the API don't accept the payload
#     145 :return: job id
#     146 """
#     147 endpoint = self.build_endpoint(_ENDPOINT_JOB_CREATE)
# --> 148 json_res = self.post_request(endpoint, payload, True)
#     149 assert _JOB_ID_KEY in json_res, f'Missing {_JOB_ID_KEY} field in create_job response'
#     150 return json_res[_JOB_ID_KEY]
#
# File ~/QFT-Cross-Verification/perceval-env/lib/python3.12/site-packages/perceval/runtime/rpc_handler.py:117, in RPCHandler.post_request(self, endpoint, payload, with_json_response)
#     115     error_info = ''.join(traceback.format_stack())
#     116     get_logger().debug(error_info, channel.general)
# --> 117     raise requests.HTTPError(f"Url: {endpoint} answered with status code {request.status_code}.")
#     119 return json_res
#
# HTTPError: Url: https://api.cloud.quandela.com/api/job answered with status code 400.
